# %%
import math
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

# Qiskit 2.x imports
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, depolarizing_error, ReadoutError

# ---------------------------
# Utilities
# ---------------------------
def plot_counts(counts, title="Counts", top_n=12):
    if not counts:
        print("No counts to plot.")
        return
    items = sorted(counts.items(), key=lambda kv: kv[1], reverse=True)[:top_n]
    labels = [k for k, _ in items]
    vals = [v for _, v in items]
    plt.figure(figsize=(max(6, 0.6 * len(labels)), 3.5))
    plt.bar(labels, vals)
    plt.title(title)
    plt.xlabel("bitstring (classical)")
    plt.ylabel("counts")
    plt.show()

def most_likely(counts):
    if not counts:
        return None
    return max(counts.items(), key=lambda kv: kv[1])[0]

def matches_target(key, target):
    """Return True if measured key matches target in either orientation (Qiskit bit-order caveat)."""
    return key == target or key[::-1] == target

# ---------------------------
# Grover Oracle & Diffuser
# ---------------------------
def mark_state_oracle(qc, qr, marked_bitstring):
    n = len(qr)
    if len(marked_bitstring) != n:
        raise ValueError("marked_bitstring length must equal number of qubits")
    # Apply X on qubits where target bit == '0' to map the marked state to |11...1>
    for i, bit in enumerate(marked_bitstring):
        if bit == '0':
            qc.x(qr[i])
    # Multi-controlled Z using H on target to convert MCX to MCZ
    if n == 1:
        qc.z(qr[0])
    else:
        qc.h(qr[-1])
        qc.mcx(qr[:-1], qr[-1])  # controls: all but last; target: last
        qc.h(qr[-1])
    # Undo the Xs
    for i, bit in enumerate(marked_bitstring):
        if bit == '0':
            qc.x(qr[i])

def diffuser(qc, qr):
    n = len(qr)
    # H on all
    qc.h(qr)
    # X on all
    qc.x(qr)
    # multi-controlled Z on all qubits
    if n == 1:
        qc.z(qr[0])
    else:
        qc.h(qr[-1])
        qc.mcx(qr[:-1], qr[-1])
        qc.h(qr[-1])
    # Undo X and H
    qc.x(qr)
    qc.h(qr)

# ---------------------------
# Build Grover circuit
# ---------------------------
def grover_circuit(n, marked, iterations=1, measure=True, draw_gate=False):
    qr = QuantumRegister(n, 'q')
    cr = ClassicalRegister(n, 'c') if measure else None
    qc = QuantumCircuit(qr, cr) if measure else QuantumCircuit(qr)

    # Initialize uniform superposition
    qc.h(qr)

    # Grover iterations
    for _ in range(iterations):
        mark_state_oracle(qc, qr, marked)
        diffuser(qc, qr)

    if measure:
        qc.measure(qr, cr)

    if draw_gate:
        # qc.draw('mpl') returns a matplotlib Figure if backend supports it
        fig = qc.draw('mpl', fold=120)
        return qc, fig
    return qc

# ---------------------------
# Simulation runners
# ---------------------------
def run_ideal(qc, shots=1024):
    backend = AerSimulator()
    tc = transpile(qc, backend=backend)
    job = backend.run(tc, shots=shots)
    res = job.result()
    return res.get_counts()

def make_simple_noise_model(p1=0.002, p2=0.01, ro=0.03):
    nm = NoiseModel()
    single = depolarizing_error(p1, 1)
    two = depolarizing_error(p2, 2)
    nm.add_all_qubit_quantum_error(single, ['u3','u2','u1','h','x'])
    nm.add_all_qubit_quantum_error(two, ['cx'])
    nm.add_all_qubit_readout_error(ReadoutError([[1-ro, ro], [ro, 1-ro]]))
    return nm

def run_noisy(qc, noise_model, shots=2048):
    backend = AerSimulator()
    tc = transpile(qc, backend=backend)
    job = backend.run(tc, shots=shots, noise_model=noise_model)
    res = job.result()
    return res.get_counts()

# ---------------------------
# Experiment runner / examples
# ---------------------------
def experiment(n, marked_states, iterations_list=None, plot=True, noisy=False):
    N = 2**n
    if iterations_list is None:
        k_opt = max(1, int(math.floor(math.pi / 4 * math.sqrt(N))))
        iterations_list = [k_opt, max(1, k_opt-1), k_opt+1]  # try around theoretical optimum

    noise_model = make_simple_noise_model() if noisy else None

    results = {}
    for marked in marked_states:
        if len(marked) != n:
            raise ValueError(f"Marked state '{marked}' length != n ({n})")
        results[marked] = {}
        for k in iterations_list:
            print(f"\n=== n={n}, marked={marked}, iterations={k} ===")
            qc, fig = grover_circuit(n, marked, iterations=k, measure=True, draw_gate=True)
            # Draw circuit (mpl)
            print("Circuit visualization (mpl figure shown).")
            display(fig)  # works in Jupyter; in scripts, the fig will appear if plt.show() is used
            # Ideal run
            counts_ideal = run_ideal(qc, shots=2048)
            print("Ideal counts (top 8):", dict(list(sorted(counts_ideal.items(), key=lambda kv: kv[1], reverse=True))[:8]))
            if plot:
                plot_counts(counts_ideal, title=f"Ideal: n={n}, marked={marked}, k={k}")
            results[marked][(k, 'ideal')] = counts_ideal

            if noisy:
                counts_noisy = run_noisy(qc, noise_model, shots=4096)
                print("Noisy counts (top 8):", dict(list(sorted(counts_noisy.items(), key=lambda kv: kv[1], reverse=True))[:8]))
                if plot:
                    plot_counts(counts_noisy, title=f"Noisy: n={n}, marked={marked}, k={k}")
                results[marked][(k, 'noisy')] = counts_noisy

            # Print success prob (check both orientations of bitstring)
            ml_ideal = most_likely(counts_ideal)
            success_ideal = sum(v for k2, v in counts_ideal.items() if matches_target(k2, marked)) / sum(counts_ideal.values())
            print(f"Ideal success probability for marked='{marked}' = {success_ideal:.4f} (most likely='{ml_ideal}')")

            if noisy:
                ml_noisy = most_likely(counts_noisy)
                success_noisy = sum(v for k2, v in counts_noisy.items() if matches_target(k2, marked)) / sum(counts_noisy.values())
                print(f"Noisy success probability for marked='{marked}' = {success_noisy:.4f} (most likely='{ml_noisy}')")
    return results

# ---------------------------
# Example usage
# ---------------------------
if __name__ == "__main__":
    # 1) For 3 qubits, try different marked states
    marked_states_3 = ['001', '111', '010']
    res3 = experiment(n=3, marked_states=marked_states_3, iterations_list=[1,2], plot=True, noisy=True)

    # 2) Extend to 4 qubits (update oracle & diffuser work for generic n)
    # Recommended iterations ~ floor(pi/4 * sqrt(2^n))
    marked_states_4 = ['0011', '1111']  # example marked states
    # compute recommended k for n=4: floor(pi/4 * sqrt(16)) = floor(pi/4 * 4) = floor(pi) = 3
    res4 = experiment(n=4, marked_states=marked_states_4, iterations_list=[1,2,3,4], plot=True, noisy=True)

    print("\nDone experiments. Inspect `res3` and `res4` dicts for raw counts.")
# Out:
# === n=3, marked=001, iterations=1 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'100': 1598, '001': 73, '011': 71, '000': 65, '101': 65, '111': 59, '110': 59, '010': 58}
# Noisy counts (top 8): {'100': 2938, '000': 241, '110': 217, '101': 214, '001': 157, '010': 127, '011': 109, '111': 93}
# Ideal success probability for marked='001' = 0.8159 (most likely='100')
# Noisy success probability for marked='001' = 0.7556 (most likely='100')
#
# === n=3, marked=001, iterations=2 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'100': 1941, '111': 21, '000': 21, '011': 20, '110': 14, '010': 12, '101': 11, '001': 8}
# Noisy counts (top 8): {'100': 3463, '110': 167, '101': 165, '000': 150, '010': 44, '001': 40, '011': 34, '111': 33}
# Ideal success probability for marked='001' = 0.9517 (most likely='100')
# Noisy success probability for marked='001' = 0.8552 (most likely='100')
#
# === n=3, marked=111, iterations=1 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'111': 1614, '110': 77, '011': 70, '101': 69, '001': 64, '000': 56, '100': 52, '010': 46}
# Noisy counts (top 8): {'111': 2933, '011': 214, '110': 207, '101': 206, '000': 150, '100': 137, '001': 128, '010': 121}
# Ideal success probability for marked='111' = 0.7881 (most likely='111')
# Noisy success probability for marked='111' = 0.7161 (most likely='111')
#
# === n=3, marked=111, iterations=2 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'111': 1938, '110': 20, '010': 17, '000': 16, '101': 16, '100': 14, '001': 14, '011': 13}
# Noisy counts (top 8): {'111': 3491, '110': 161, '101': 145, '011': 141, '010': 48, '001': 40, '000': 35, '100': 35}
# Ideal success probability for marked='111' = 0.9463 (most likely='111')
# Noisy success probability for marked='111' = 0.8523 (most likely='111')
#
# === n=3, marked=010, iterations=1 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'010': 1613, '111': 67, '000': 65, '100': 65, '011': 62, '101': 61, '001': 60, '110': 55}
# Noisy counts (top 8): {'010': 2932, '000': 225, '110': 223, '011': 205, '101': 134, '001': 131, '111': 127, '100': 119}
# Ideal success probability for marked='010' = 0.7876 (most likely='010')
# Noisy success probability for marked='010' = 0.7158 (most likely='010')
#
# === n=3, marked=010, iterations=2 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'010': 1914, '101': 23, '110': 22, '000': 21, '111': 19, '011': 19, '100': 16, '001': 14}
# Noisy counts (top 8): {'010': 3479, '000': 165, '011': 156, '110': 149, '001': 45, '100': 41, '111': 32, '101': 29}
# Ideal success probability for marked='010' = 0.9346 (most likely='010')
# Noisy success probability for marked='010' = 0.8494 (most likely='010')
#
# === n=4, marked=0011, iterations=1 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1100': 961, '0111': 84, '0000': 83, '1000': 82, '1001': 79, '0001': 77, '1111': 76, '0100': 74}
# Noisy counts (top 8): {'1100': 1707, '0100': 196, '1110': 186, '1101': 183, '1000': 182, '1010': 169, '0000': 167, '0101': 165}
# Ideal success probability for marked='0011' = 0.5049 (most likely='1100')
# Noisy success probability for marked='0011' = 0.4507 (most likely='1100')
#
# === n=4, marked=0011, iterations=2 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1100': 1863, '1110': 20, '0110': 16, '1001': 15, '1111': 14, '1010': 14, '0111': 13, '1101': 13}
# Noisy counts (top 8): {'1100': 3257, '1000': 129, '1110': 129, '0100': 125, '1101': 120, '0011': 34, '0000': 34, '0101': 33}
# Ideal success probability for marked='0011' = 0.9141 (most likely='1100')
# Noisy success probability for marked='0011' = 0.8035 (most likely='1100')
#
# === n=4, marked=0011, iterations=3 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1100': 1981, '0000': 7, '1101': 6, '1001': 6, '1011': 6, '0100': 5, '0111': 5, '1000': 5}
# Noisy counts (top 8): {'1100': 3402, '0100': 146, '1110': 124, '1101': 122, '1000': 113, '1001': 24, '0110': 22, '0101': 21}
# Ideal success probability for marked='0011' = 0.9688 (most likely='1100')
# Noisy success probability for marked='0011' = 0.8337 (most likely='1100')
#
# === n=4, marked=0011, iterations=4 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1100': 1166, '0110': 73, '0001': 71, '1111': 65, '0100': 63, '0111': 61, '1010': 60, '1110': 60}
# Noisy counts (top 8): {'1100': 2003, '1000': 212, '1101': 180, '1110': 177, '0100': 174, '0010': 141, '0101': 131, '1010': 130}
# Ideal success probability for marked='0011' = 0.5913 (most likely='1100')
# Noisy success probability for marked='0011' = 0.5188 (most likely='1100')
#
# === n=4, marked=1111, iterations=1 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1111': 993, '0010': 83, '0101': 79, '1011': 77, '0011': 76, '1001': 75, '1000': 73, '0111': 73}
# Noisy counts (top 8): {'1111': 1717, '0111': 216, '1011': 210, '1110': 193, '1101': 185, '1100': 155, '1000': 154, '1010': 149}
# Ideal success probability for marked='1111' = 0.4849 (most likely='1111')
# Noisy success probability for marked='1111' = 0.4192 (most likely='1111')
#
# === n=4, marked=1111, iterations=2 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1111': 1857, '0100': 18, '1001': 18, '0111': 18, '1010': 15, '0110': 15, '1101': 14, '0101': 13}
# Noisy counts (top 8): {'1111': 3213, '1101': 153, '1110': 145, '1011': 130, '0111': 126, '1000': 40, '0011': 37, '1001': 33}
# Ideal success probability for marked='1111' = 0.9067 (most likely='1111')
# Noisy success probability for marked='1111' = 0.7844 (most likely='1111')
#
# === n=4, marked=1111, iterations=3 ===
# Circuit visualization (mpl figure shown).
# Ideal counts (top 8): {'1111': 1972, '0111': 8, '1000': 7, '0001': 7, '1110': 7, '0011': 6, '0100': 6, '1001': 6}
